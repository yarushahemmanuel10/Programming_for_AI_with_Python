# %%
from functools import reduce

# %%
numbers = [1,2,3,4,5]

# %%
result = reduce(lambda x, y: x + y, numbers)
print(result)
# Out:
# 15

# %%
result = reduce(lambda x, y: x + y, numbers)

# %%
 
args_for_10 = list (range (1, 11))

# %%
result = reduce(lambda x, y : x * y, args_for_10)

# %%
result
# Out:
# 3628800

# %%
args_for_17 = list(range(1,18))

# %%
print(args_for_5)
# Out:
# [1, 2, 3, 4, 5]

# %%
result_17 = reduce(lambda x, y : x * y, args_for_17)

# %%
print(result_17)
# Out:
# 355687428096000

# %%
args_for_22 = list(range(1,23))

# %%
result_22 = reduce(lambda x, y : x * y, args_for_22)

# %%
print(result_22)
# Out:
# 1124000727777607680000

# %%
num = 22

# %%
import math
result = math.factorial(num)
print(result)
# Out:
# 1124000727777607680000

# %%
result_5 = reduce(lambda x, y : x * y, args_for_22)

# %%
n = 22
print(reduce(lambda x, y: x * y, range(1, n + 1)))
# Out:
# 1124000727777607680000

# %%
def Factorial(n):
    z = reduce(lambda x, y: x * y, range(1, n + 1))
    return z

# %%
print('Factorial for 10: ', Factorial(10))
# Out:
# Factorial for 10:  3628800

# %%
print('Factorial for 17: ', Factorial(17))
# Out:
# Factorial for 17:  355687428096000

# %%
print('Factorial for 22: ', Factorial(22))
# Out:
# Factorial for 22:  1124000727777607680000

# %%
result_10 = math.factorial(10)

# %%
def Factorial(n):
    z = reduce(lambda x, y: x * y, range(1, n + 1))
    return z

print('Factorial for 10: ', Factorial(10))
print('Factorial for 17: ', Factorial(17))
print('Factorial for 22: ', Factorial(22))
# Out:
# Factorial for 10:  3628800
# Factorial for 17:  355687428096000
# Factorial for 22:  1124000727777607680000

# %%
result_10 = math.factorial(10)
print('Factorial for 10: ', result_10)
result_17 = math.factorial(17)
print('Factorial for 17: ', result_17)
result_22 = math.factorial(22)
print('Factorial for 22: ', result_22)
# Out:
# Factorial for 10:  3628800
# Factorial for 17:  355687428096000
# Factorial for 22:  1124000727777607680000
