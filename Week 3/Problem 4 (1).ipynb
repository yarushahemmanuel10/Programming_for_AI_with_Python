# %% [markdown]
# 4. Using a lambda, implement a map() that accepts a list of lists and returns
# the sums of the sublists.
#
# [[1, 5, 3], [3, 6], [9, 11, 45, 11], [5, 2, 6, 3, 7]] à [9, 9, 76, 23]

# %%
z = [[1, 5, 3], [3, 6], [9, 11, 45, 11], [5, 2, 6, 3, 7]]

# %%
list((map(lambda x: sum(x),z)))
# Out:
# [9, 9, 76, 23]
