# %%
values_list = [4, 12, 2, 9, 10, 11, 5, 9, 33]
total = 0
list= []

for i, value in enumerate(values_list):
    if value > 10:
        list.append(i)
        total = sum(list)
        
   # print(value, i)
# write your logic here
print(total)
# Out:
# 14
