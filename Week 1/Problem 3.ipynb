# %%
values1 = [4, 6, 2, 9, 10, 11, 24, 50, 33]
values2 = [3, 5, 24, 12, 13, 4, 20, 10, 6] 
total = 0
list= []

for i in values1:
    for j in values2:
        if i==j:
            list.append(i)
            total= sum(list)
           # total= i+j
print(total)
# write your logic here
# Out:
# 44
